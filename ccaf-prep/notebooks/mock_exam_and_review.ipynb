# %% [markdown]
# # Mock exam & review — CCAF
#
# The consolidation surface for the whole exam. Use it two ways:
#
# - **Progressively** — after you finish each domain notebook, tick that domain's boxes in
#   **Part A** (coverage) and **Part C** (prep recommendations).
# - **At the end** — once all 5 notebooks and all 5 exercises are done, work through the
#   scenario-grouped **mock (Part D)** under timed conditions, confirm Part A is fully ticked,
#   then sit the official Practice Exam.
#
# Order of study and exercises: see [`README.md`](./README.md).

# %% [markdown]
# ## Part A — Coverage checklist (tick per domain as you finish it)
#
# Two lists per domain, from the guide's **In-Scope Topics** and **Technologies & Concepts**.
# Tick each box when the matching notebook section is done.
#
# ### Domain 1 — Agentic Architecture & Orchestration (27%)
# *Notebook: `D1_agentic_loops.ipynb`*
#
# **In-Scope topics**
#
# - [ ] Agentic loop implementation: control flow based on `stop_reason`, tool result handling, loop termination (§1.1)
# - [ ] Multi-agent orchestration: coordinator-subagent patterns, task decomposition, parallel subagent execution, iterative refinement (§1.2, §1.6)
# - [ ] Subagent context management: explicit context passing, structured state persistence (§1.3)
#
# **Technologies & Concepts**
#
# - [ ] **Claude Agent SDK** — Agent definitions, agentic loops, `stop_reason` handling, hooks (PostToolUse, tool call interception), subagent spawning via `Task` tool, `allowedTools` configuration (§1.2–1.5)
# - [ ] **Prompt chaining** — sequential task decomposition into focused passes (§1.6)
# - [ ] **Session management** — session resumption, `fork_session`, named sessions, session context isolation (§1.7)
# - [ ] **Claude API** — `stop_reason` values (`"tool_use"`, `"end_turn"`) (§1.1)
#
# ### Domain 2 — Tool Design & MCP Integration (18%)
# *Notebook: `D2_tool_design_mcp.ipynb`*
#
# **In-Scope topics**
#
# - [ ] Tool interface design: writing effective tool descriptions, splitting vs consolidating tools, tool naming to reduce ambiguity (§2.1)
# - [ ] MCP tool and resource design: resources for content catalogs, tools for actions, description quality for adoption (§2.4)
# - [ ] MCP server configuration: project vs user scope, environment variable expansion, multi-server simultaneous access (§2.4)
# - [ ] Error handling and propagation: structured error responses, transient vs business vs permission errors (§2.2) — *propagation across agents is also D5 §5.3*
#
# **Technologies & Concepts**
#
# - [ ] **Model Context Protocol (MCP)** — MCP servers, MCP tools, MCP resources, `isError` flag, tool descriptions, tool distribution, `.mcp.json` configuration, environment variable expansion (§2.1–2.4)
# - [ ] **Built-in tools** — Read, Write, Edit, Bash, Grep, Glob — their purposes and selection criteria (§2.5)
#
# ### Domain 5 — Context Management & Reliability (15%)
# *Notebook: `D5_*.ipynb` (to build)*
#
# **In-Scope topics**
#
# - [ ] Escalation decision-making: explicit criteria, honoring customer preferences, policy gap identification (§5.2)
# - [ ] Context window optimization: trimming verbose tool outputs, structured fact extraction, position-aware input ordering (§5.1)
# - [ ] Human review workflows: confidence calibration, stratified sampling, accuracy segmentation by document type and field (§5.5)
# - [ ] Information provenance: claim-source mappings, temporal data handling, conflict annotation, coverage gap reporting (§5.6)
# - [ ] Error handling and propagation: structured error context, access-failure vs empty-result (§5.3)
#
# **Technologies & Concepts**
#
# - [ ] **Context window management** — token budgets, progressive summarization, lost-in-the-middle effects, context extraction, scratchpad files (§5.1, §5.4)
# - [ ] **Confidence scoring** — field-level confidence, calibration with labeled validation sets, stratified sampling for error rate measurement (§5.5)
#
# ### Domain 3 — Claude Code Configuration & Workflows (20%)
# *Notebook: `D3_*.ipynb` (to build)*
#
# **In-Scope topics**
#
# - [ ] CLAUDE.md configuration: hierarchy (user/project/directory), `@import` patterns, `.claude/rules/` with glob patterns (§3.1, §3.3)
# - [ ] Custom commands and skills: project vs user scope, `context: fork`, `allowed-tools`, `argument-hint` frontmatter (§3.2)
# - [ ] Plan mode vs direct execution: complexity assessment, architectural decisions, single-file changes (§3.4)
# - [ ] Iterative refinement: input/output examples, test-driven iteration, interview pattern, sequential vs parallel issue resolution (§3.5)
#
# **Technologies & Concepts**
#
# - [ ] **Claude Code** — CLAUDE.md hierarchy (user/project/directory), `.claude/rules/` YAML path-scoping, `.claude/commands/`, `.claude/skills/` SKILL.md frontmatter (`context: fork`, `allowed-tools`, `argument-hint`), plan mode, direct execution, `/memory`, `/compact`, `--resume`, `fork_session`, Explore subagent (§3.1–3.4)
# - [ ] **Claude Code CLI** — `-p` / `--print` for non-interactive mode, `--output-format json`, `--json-schema` for structured CI output (§3.6)
#
# ### Domain 4 — Prompt Engineering & Structured Output (20%)
# *Notebook: `D4_*.ipynb` (to build)*
#
# **In-Scope topics**
#
# - [ ] Structured output via `tool_use`: schema design, `tool_choice` configuration, nullable fields to prevent hallucination (§4.3)
# - [ ] Few-shot prompting: ambiguous scenario targeting, format consistency, false positive reduction (§4.1, §4.2)
# - [ ] Batch processing: Message Batches API appropriateness, latency tolerance, failure handling by `custom_id` (§4.5)
# - [ ] Multi-pass review architectures (§4.6) — *also D1 §1.6*
#
# **Technologies & Concepts**
#
# - [ ] **Claude API** — `tool_use` with JSON schemas, `tool_choice` options (`"auto"`, `"any"`, forced tool selection), `max_tokens`, system prompts (§4.3)
# - [ ] **Message Batches API** — 50% cost savings, up to 24-hour window, `custom_id` correlation, polling, no multi-turn tool calling (§4.5)
# - [ ] **JSON Schema** — required vs optional fields, enum types, nullable fields, `"other"` + detail patterns, strict mode (§4.3)
# - [ ] **Pydantic** — schema validation, semantic validation errors, validation-retry loops (§4.4)
# - [ ] **Few-shot prompting** — targeted examples for ambiguous scenarios, format demonstration, generalization (§4.2)

# %% [markdown]
# ## Part B — Out-of-Scope (read once, then do NOT study these)
#
# The guide is explicit that these will **not** appear. Don't burn time here.
#
# - Fine-tuning Claude models or training custom models
# - Claude API authentication, billing, or account management
# - Detailed implementation of specific programming languages or frameworks (beyond what's needed for tool and schema configuration)
# - Deploying or hosting MCP servers (infrastructure, networking, container orchestration)
# - Claude's internal architecture, training process, or model weights
# - Constitutional AI, RLHF, or safety training methodologies
# - Embedding models or vector database implementation details
# - Computer use (browser automation, desktop interaction)
# - Vision/image analysis capabilities
# - Streaming API implementation or server-sent events
# - Rate limiting, quotas, or API pricing calculations
# - OAuth, API key rotation, or authentication protocol details
# - Specific cloud provider configurations (AWS, GCP, Azure)
# - Performance benchmarking or model comparison metrics
# - Prompt caching implementation details (beyond knowing it exists)
# - Token counting algorithms or tokenization specifics

# %% [markdown]
# ## Part C — Readiness: the 8 prep recommendations (tick as you cover them)
#
# Each official recommendation, mapped to where you do it.
#
# - [ ] **1. Build an agent with the Claude Agent SDK** — complete agentic loop with tool calling, error handling, session management; spawn subagents and pass context. → **D1** notebook + **Ex1**, **Ex4**
# - [ ] **2. Configure Claude Code for a real project** — CLAUDE.md hierarchy, path-specific rules in `.claude/rules/`, custom skills (`context: fork`, `allowed-tools`), integrate ≥1 MCP server. → **D3** notebook + **Ex2**
# - [ ] **3. Design and test MCP tools** — differentiate similar tools via descriptions; structured error responses with categories + retryable flags; test selection with ambiguous requests. → **D2** notebook + **Ex1**, **Ex3**
# - [ ] **4. Build a structured data extraction pipeline** — `tool_use` + JSON schemas, validation-retry loops, optional/nullable fields, Message Batches API. → **D4** notebook + **Ex3**
# - [ ] **5. Practice prompt engineering techniques** — few-shot for ambiguous scenarios, explicit review criteria to cut false positives, multi-pass review for large code reviews. → **D4** notebook + **Ex3**, **Ex5**
# - [ ] **6. Study context management patterns** — extract structured facts from verbose tool outputs, scratchpad files for long sessions, subagent delegation to manage context limits. → **D5** notebook + **Ex4**
# - [ ] **7. Review escalation and human-in-the-loop patterns** — when to escalate (policy gaps, customer requests, no progress) vs resolve; human review workflows with confidence routing. → **D5** notebook + **Ex1**, **Ex3**
# - [ ] **8. Complete the official Practice Exam** (Skilljar) — same scenarios and format as the real exam; review explanations after each answer. → after everything above

# %% [markdown]
# ## Part D — Mock exam
# <!-- ccaf:redacted -->
#
# See the official **Claude Certified Architect – Foundations** exam guide for its sample
# questions. For a full-length practice run, use **`practice_exam_A.ipynb`** — 33 original
# scenario-based items across all six scenarios.
